# %% [markdown]
# # This script should help split out data into train and test data.
# We have decided to train the model on the data from the years 2022 and 2023, then test on the data from 2024.

# %%
import pandas as pd
import os

# %%
path_to_data = '../data/raw/Intuilize_MNSU_ACME_SalesData.csv'

# %%
data = pd.read_csv(path_to_data)

# %%
data['SalesDate'] = pd.to_datetime(data['SalesDate'])
data["Month"] = data["SalesDate"].dt.month
data["Year"] = data["SalesDate"].dt.year
# Calculate profit
data["Profit"] = data["ExtPrice"] - data["ExtCost"]

# %% [markdown]
# removing 2021 and 2025 data as they are incomplete

# %%
data = data.drop(data[data["Year"].isin([2021, 2025])].index)

# %%
unique_customers = data['CustomerName'].unique()
name_to_alias = {name: f"Customer {i+1}" for i, name in enumerate(unique_customers)}
data['customer_alias'] = data['CustomerName'].map(name_to_alias)

# %%
data.columns
# Out:
# Index(['BranchName', 'Ship2City', 'Ship2State', 'OrderNumber', 'InvoiceNumber',
#        'LineNumber', 'OrderDate', 'SalesDate', 'SalesPersonID',
#        'SalesPersonName', 'ProductID', 'ProductGroupID', 'CustomerID',
#        'CustomerName', 'ExtPrice', 'ExtCost', 'SalesQty', 'UnitPrice',
#        'UnitCost', 'UOM', 'UnitSize', 'Month', 'Year', 'Profit',
#        'customer_alias'],
#       dtype='object')

# %%
_2022_and_2023_data = data[data["Year"].isin([2022, 2023])]
_2024_data = data[data["Year"] == 2024]
#split 2022 & 2023 data into Monthly chunks
_2022_data = _2022_and_2023_data[_2022_and_2023_data["Year"] == 2022]
_2023_data = _2022_and_2023_data[_2022_and_2023_data["Year"] == 2023]
_2022_1_data = _2022_data[_2022_data["Month"].isin([1])]
_2022_2_data = _2022_data[_2022_data["Month"].isin([2])]
_2022_3_data = _2022_data[_2022_data["Month"].isin([3])]
_2022_4_data = _2022_data[_2022_data["Month"].isin([4])]
_2022_5_data = _2022_data[_2022_data["Month"].isin([5])]
_2022_6_data = _2022_data[_2022_data["Month"].isin([6])]
_2022_7_data = _2022_data[_2022_data["Month"].isin([7])]
_2022_8_data = _2022_data[_2022_data["Month"].isin([8])]
_2022_9_data = _2022_data[_2022_data["Month"].isin([9])]
_2022_10_data = _2022_data[_2022_data["Month"].isin([10])]
_2022_11_data = _2022_data[_2022_data["Month"].isin([11])]
_2022_12_data = _2022_data[_2022_data["Month"].isin([12])]
_2023_1_data = _2023_data[_2023_data["Month"].isin([1])]
_2023_2_data = _2023_data[_2023_data["Month"].isin([2])]
_2023_3_data = _2023_data[_2023_data["Month"].isin([3])]
_2023_4_data = _2023_data[_2023_data["Month"].isin([4])]
_2023_5_data = _2023_data[_2023_data["Month"].isin([5])]
_2023_6_data = _2023_data[_2023_data["Month"].isin([6])]
_2023_7_data = _2023_data[_2023_data["Month"].isin([7])]
_2023_8_data = _2023_data[_2023_data["Month"].isin([8])]
_2023_9_data = _2023_data[_2023_data["Month"].isin([9])]
_2023_10_data = _2023_data[_2023_data["Month"].isin([10])]
_2023_11_data = _2023_data[_2023_data["Month"].isin([11])]
_2023_12_data = _2023_data[_2023_data["Month"].isin([12])]
# split 2024 data into Monthly chunks
_2024_1_data = _2024_data[_2024_data["Month"].isin([1])]
_2024_2_data = _2024_data[_2024_data["Month"].isin([2])]
_2024_3_data = _2024_data[_2024_data["Month"].isin([3])]
_2024_4_data = _2024_data[_2024_data["Month"].isin([4])]
_2024_5_data = _2024_data[_2024_data["Month"].isin([5])]
_2024_6_data = _2024_data[_2024_data["Month"].isin([6])]
_2024_7_data = _2024_data[_2024_data["Month"].isin([7])]
_2024_8_data = _2024_data[_2024_data["Month"].isin([8])]
_2024_9_data = _2024_data[_2024_data["Month"].isin([9])]
_2024_10_data = _2024_data[_2024_data["Month"].isin([10])]
_2024_11_data = _2024_data[_2024_data["Month"].isin([11])]  
_2024_12_data = _2024_data[_2024_data["Month"].isin([12])]

# %%
# Create dictionaries for each year
data_2022_dict = {month: _2022_and_2023_data[_2022_and_2023_data["Year"] == 2022][_2022_and_2023_data["Month"] == month] for month in range(1, 13)}
data_2023_dict = {month: _2022_and_2023_data[_2022_and_2023_data["Year"] == 2023][_2022_and_2023_data["Month"] == month] for month in range(1, 13)}
data_2024_dict = {month: _2024_data[_2024_data["Month"] == month] for month in range(1, 13)}
# Out:
# C:\Users\andyh\AppData\Local\Temp\ipykernel_3324\590771286.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_2022_dict = {month: _2022_and_2023_data[_2022_and_2023_data["Year"] == 2022][_2022_and_2023_data["Month"] == month] for month in range(1, 13)}
# C:\Users\andyh\AppData\Local\Temp\ipykernel_3324\590771286.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_2022_dict = {month: _2022_and_2023_data[_2022_and_2023_data["Year"] == 2022][_2022_and_2023_data["Month"] == month] for month in range(1, 13)}
# C:\Users\andyh\AppData\Local\Temp\ipykernel_3324\590771286.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_2022_dict = {month: _2022_and_2023_data[_2022_and_2023_data["Year"] == 2022][_2022_and_2023_data["Month"] == month] for month in range(1, 13)}
# ...

# %% [markdown]
# # train_data.csv contains all the data from 2022 and 2023
# # test_data.csv contains all the data from 2024

# %%
# Aggregate revenue, profit, and frequency per customer while ensuring CustomerID is retained
customer_metrics = data.groupby(["CustomerID", "CustomerName"]).agg(
    TotalRevenue=("ExtPrice", "sum"),
    TotalProfit=("Profit", "sum"),
    PurchaseFrequency=("OrderNumber", "nunique"),
).reset_index()

# %%
# _2022_and_2023_data.to_csv("../data/cleaned/train_data.csv")
# _2024_data.to_csv("../data/cleaned/test_data.csv")
# customer_metrics.to_csv("../data/cleaned/customer_metrics.csv")
# data.to_csv("../data/cleaned/raw_data_extra_features.csv") # removed 2021 and 2025 and have profit, month, and year

if not os.path.exists('../data/cleaned/monthlydata'):
    os.makedirs('../data/cleaned/monthlydata')

_2022_1_data.to_csv("../data/cleaned/monthlydata/2022_1_data.csv")
_2022_2_data.to_csv("../data/cleaned/monthlydata/2022_2_data.csv")
_2022_3_data.to_csv("../data/cleaned/monthlydata/2022_3_data.csv")
_2022_4_data.to_csv("../data/cleaned/monthlydata/2022_4_data.csv")
_2022_5_data.to_csv("../data/cleaned/monthlydata/2022_5_data.csv")
_2022_6_data.to_csv("../data/cleaned/monthlydata/2022_6_data.csv")
_2022_7_data.to_csv("../data/cleaned/monthlydata/2022_7_data.csv")
_2022_8_data.to_csv("../data/cleaned/monthlydata/2022_8_data.csv")
_2022_9_data.to_csv("../data/cleaned/monthlydata/2022_9_data.csv")
_2022_10_data.to_csv("../data/cleaned/monthlydata/2022_10_data.csv")
_2022_11_data.to_csv("../data/cleaned/monthlydata/2022_11_data.csv")
_2022_12_data.to_csv("../data/cleaned/monthlydata/2022_12_data.csv")
_2023_1_data.to_csv("../data/cleaned/monthlydata/2023_1_data.csv")
_2023_2_data.to_csv("../data/cleaned/monthlydata/2023_2_data.csv")
_2023_3_data.to_csv("../data/cleaned/monthlydata/2023_3_data.csv")
_2023_4_data.to_csv("../data/cleaned/monthlydata/2023_4_data.csv")
_2023_5_data.to_csv("../data/cleaned/monthlydata/2023_5_data.csv")
_2023_6_data.to_csv("../data/cleaned/monthlydata/2023_6_data.csv")
_2023_7_data.to_csv("../data/cleaned/monthlydata/2023_7_data.csv")
_2023_8_data.to_csv("../data/cleaned/monthlydata/2023_8_data.csv")
_2023_9_data.to_csv("../data/cleaned/monthlydata/2023_9_data.csv")
_2023_10_data.to_csv("../data/cleaned/monthlydata/2023_10_data.csv")
_2023_11_data.to_csv("../data/cleaned/monthlydata/2023_11_data.csv")
_2023_12_data.to_csv("../data/cleaned/monthlydata/2023_12_data.csv")

# %%
# save test data
if not os.path.exists('../data/cleaned/monthlydata/test'):
    os.makedirs('../data/cleaned/monthlydata/test')

_2024_1_data.to_csv("../data/cleaned/monthlydata/test/2024_1_data.csv")
_2024_2_data.to_csv("../data/cleaned/monthlydata/test/2024_2_data.csv")
_2024_3_data.to_csv("../data/cleaned/monthlydata/test/2024_3_data.csv")
_2024_4_data.to_csv("../data/cleaned/monthlydata/test/2024_4_data.csv")
_2024_5_data.to_csv("../data/cleaned/monthlydata/test/2024_5_data.csv")
_2024_6_data.to_csv("../data/cleaned/monthlydata/test/2024_6_data.csv")
_2024_7_data.to_csv("../data/cleaned/monthlydata/test/2024_7_data.csv")
_2024_8_data.to_csv("../data/cleaned/monthlydata/test/2024_8_data.csv")
_2024_9_data.to_csv("../data/cleaned/monthlydata/test/2024_9_data.csv")
_2024_10_data.to_csv("../data/cleaned/monthlydata/test/2024_10_data.csv")
_2024_11_data.to_csv("../data/cleaned/monthlydata/test/2024_11_data.csv")
_2024_12_data.to_csv("../data/cleaned/monthlydata/test/2024_12_data.csv")
